# %%
import os, shutil
import errno

# %%
def make_sure_path_exists(path):
    try:
        os.makedirs(path)
    except OSError as exception:
        if exception.errno != errno.EEXIST:
            raise

# %%
original_dataset_dir = './Images/Kaggle/train/'

# %%
base_dir = './Images/Kaggle/cats_and_dogs'

# %%
make_sure_path_exists(base_dir)

# %%
a_name = ['train', 'validation', 'test']
b_name = ['cats', 'dogs']

# %%
#print(os.path.exists(base_dir+'/train'))

# %%
for a in a_name:
    for b in b_name:
        make_sure_path_exists(base_dir+'/'+a+'/'+b)
        print(base_dir+'/'+a+'/'+b)
# Out:
# ./Images/Kaggle/cats_and_dogs/train/cats
# ./Images/Kaggle/cats_and_dogs/train/dogs
# ./Images/Kaggle/cats_and_dogs/validation/cats
# ./Images/Kaggle/cats_and_dogs/validation/dogs
# ./Images/Kaggle/cats_and_dogs/test/cats
# ./Images/Kaggle/cats_and_dogs/test/dogs

# %%
fnames = os.listdir('./Images/Kaggle/train/')
for x in sorted_list:
    #if 'cat' in x:
        print(x)
# Out:
# cat.0.jpg
# cat.1.jpg
# cat.10.jpg
# cat.100.jpg
# cat.1000.jpg
# cat.10000.jpg
# cat.10001.jpg
# cat.10002.jpg
# cat.10003.jpg
# cat.10004.jpg
# cat.10005.jpg
# cat.10006.jpg
# cat.10007.jpg
# cat.10008.jpg
# cat.10009.jpg
# cat.1001.jpg
# cat.10010.jpg
# cat.10011.jpg
# cat.10012.jpg
# cat.10013.jpg
# cat.10014.jpg
# cat.10015.jpg
# cat.10016.jpg
# cat.10017.jpg
# cat.10018.jpg
# cat.10019.jpg
# cat.1002.jpg
# cat.10020.jpg
# cat.10021.jpg
# cat.10022.jpg
# cat.10023.jpg
# cat.10024.jpg
# cat.10025.jpg
# cat.10026.jpg
# cat.10027.jpg
# cat.10028.jpg
# cat.10029.jpg
# cat.1003.jpg
# cat.10030.jpg
# cat.10031.jpg
# cat.10032.jpg
# cat.10033.jpg
# cat.10034.jpg
# cat.10035.jpg
# cat.10036.jpg
# cat.10037.jpg
# cat.10038.jpg
# cat.10039.jpg
# cat.1004.jpg
# cat.10040.jpg
# cat.10041.jpg
# cat.10042.jpg
# cat.10043.jpg
# cat.10044.jpg
# cat.10045.jpg
# cat.10046.jpg
# cat.10047.jpg
# cat.10048.jpg
# cat.10049.jpg
# cat.1005.jpg
# cat.10050.jpg
# cat.10051.jpg
# cat.10052.jpg
# ...

# %%
print(os.listdir(original_dataset_dir))
print(os.path.join(original_dataset_dir, "cat"))
# Out:
# ['cat.8146.jpg', 'dog.796.jpg', 'dog.1504.jpg', 'dog.6797.jpg', 'cat.4551.jpg', 'cat.8915.jpg', 'dog.5406.jpg', 'dog.11767.jpg', 'dog.8413.jpg', 'dog.10713.jpg', 'dog.7052.jpg', 'cat.10834.jpg', 'cat.10271.jpg', 'cat.965.jpg', 'cat.8097.jpg', 'dog.11295.jpg', 'cat.4998.jpg', 'cat.3970.jpg', 'cat.11511.jpg', 'dog.7545.jpg', 'cat.9353.jpg', 'dog.8728.jpg', 'cat.6610.jpg', 'dog.4054.jpg', 'cat.11814.jpg', 'cat.11559.jpg', 'cat.9388.jpg', 'dog.1711.jpg', 'dog.2134.jpg', 'dog.12048.jpg', 'cat.9980.jpg', 'dog.3063.jpg', 'dog.7367.jpg', 'cat.774.jpg', 'dog.7196.jpg', 'cat.1309.jpg', 'cat.3057.jpg', 'cat.8434.jpg', 'dog.2160.jpg', 'cat.9587.jpg', 'cat.5390.jpg', 'cat.997.jpg', 'dog.6985.jpg', 'dog.6663.jpg', 'dog.4048.jpg', 'cat.8285.jpg', 'dog.8139.jpg', 'dog.5585.jpg', 'dog.3421.jpg', 'cat.7523.jpg', 'cat.9938.jpg', 'cat.2923.jpg', 'cat.5214.jpg', 'cat.1415.jpg', 'dog.2669.jpg', 'dog.1917.jpg', 'dog.2333.jpg', 'dog.7832.jpg', 'dog.4109.jpg', 'dog.628.jpg', 'dog.527.jpg', 'cat.10086.jpg', '
# ...

# %%
os.path.exists(os.path.join(base_dir+'/'+a_name[name_index]+'/'+b_name[0]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-a0f6c715ced9> in <module>
# ----> 1 os.path.exists(os.path.join(base_dir+'/'+a_name[name_index]+'/'+b_name[0]))
#
# IndexError: list index out of range

# %%
name_index = 0
count = 0
cat_names = ['cat.{}.jpg'.format(i) for i in range(2000)]
for fname in cat_names:
    count += 1
    src = os.path.join(original_dataset_dir, fname)
    des = os.path.join(base_dir+'/'+a_name[name_index]+'/'+b_name[0]+ '/' + fname)
    shutil.copyfile(src, des)
    print(count)
    print(src + '  TO  ' + des)
    
    if count == 1000:
        name_index += 1
    elif count == 1500:
        name_index += 1
    elif count == 2000:
        name_index += 1
# Out:
# 1
# ./Images/Kaggle/train/cat.0.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/cats/cat.0.jpg
# 2
# ./Images/Kaggle/train/cat.1.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/cats/cat.1.jpg
# 3
# ./Images/Kaggle/train/cat.2.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/cats/cat.2.jpg
# 4
# ./Images/Kaggle/train/cat.3.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/cats/cat.3.jpg
# 5
# ./Images/Kaggle/train/cat.4.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/cats/cat.4.jpg
# 6
# ./Images/Kaggle/train/cat.5.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/cats/cat.5.jpg
# 7
# ./Images/Kaggle/train/cat.6.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/cats/cat.6.jpg
# 8
# ./Images/Kaggle/train/cat.7.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/cats/cat.7.jpg
# 9
# ./Images/Kaggle/train/cat.8.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/cats/cat.8.jpg
# 10
# ./Images/Kaggle/train/cat.9.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/cats/cat.9.jpg
# 11
# ...

# %%
name_index = 0
count = 0
cat_names = ['dog.{}.jpg'.format(i) for i in range(2000)]
for fname in cat_names:
    count += 1
    src = os.path.join(original_dataset_dir, fname)
    des = os.path.join(base_dir+'/'+a_name[name_index]+'/'+b_name[1]+ '/' + fname)
    shutil.copyfile(src, des)
    print(count)
    print(src + '  TO  ' + des)
    
    if count == 1000:
        name_index += 1
    elif count == 1500:
        name_index += 1
    elif count == 2000:
        name_index += 1
# Out:
# 1
# ./Images/Kaggle/train/dog.0.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/dogs/dog.0.jpg
# 2
# ./Images/Kaggle/train/dog.1.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/dogs/dog.1.jpg
# 3
# ./Images/Kaggle/train/dog.2.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/dogs/dog.2.jpg
# 4
# ./Images/Kaggle/train/dog.3.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/dogs/dog.3.jpg
# 5
# ./Images/Kaggle/train/dog.4.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/dogs/dog.4.jpg
# 6
# ./Images/Kaggle/train/dog.5.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/dogs/dog.5.jpg
# 7
# ./Images/Kaggle/train/dog.6.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/dogs/dog.6.jpg
# 8
# ./Images/Kaggle/train/dog.7.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/dogs/dog.7.jpg
# 9
# ./Images/Kaggle/train/dog.8.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/dogs/dog.8.jpg
# 10
# ./Images/Kaggle/train/dog.9.jpg  TO  ./Images/Kaggle/cats_and_dogs/train/dogs/dog.9.jpg
# 11
# ...

# %%
for a in a_name:
    for b in b_name:

# %%
'''
if not os.path.exists(base_dir+'/train'):
    train_dir = os.path.join(base_dir, 'train')
    os.mkdir(train_dir)

if not os.path.exists(base_dir+'/validation'):
    validation_dir = os.path.join(base_dir, 'validation')
    os.mkdir(validation_dir)

if not os.path.exists(base_dir+'/test'): 
    test_dir = os.path.join(base_dir, 'test')
    os.mkdir(test_dir)
'''

# %%
for x in folder_name:
    if not os.path.exists(train_dir+'/cats'):
        train_cats_dir = os.path.join(train_dir, 'cats')
    if not os.path.exists(train_dir+'/dogs'):
        tring_dogs_dir = os.path.join(train__dir, 'dogs')
# Out:
# train
# validation
# test

# %%
os.listdir(base_dir)
# Out:
# ['train', 'test', 'validation']

# %%
print(os.listdir())
os.chdir('./Images')
# Out:
# ['test', 'nohup.out', 'lost+found', 'Anaconda2-2019.07-Linux-x86_64.sh', 'Untitled.ipynb', 'Images', 'knj', 'sw', 'ttt.ipynb', '006958-master', '.ipynb_checkpoints']

# %%
# Out:
# ['Kaggle', 'LSVRC', 'COCO', 'Pascal', '.ipynb_checkpoints', 'Caltech']
